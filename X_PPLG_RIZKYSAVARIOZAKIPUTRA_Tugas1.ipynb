# %% [markdown]
# <a href="https://colab.research.google.com/github/RizkySavarioZakiPutra/DasarPPLGX/blob/main/X_PPLG_RIZKYSAVARIOZAKIPUTRA_Tugas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tugas1 Praktik Membuat Tipe Dan Variable
# Nama Kelompok: NovaCrew
# Nama Anggota:
# 1.Azril
# 2.Rizky
# 3.Rafa Maul
# 4.Dava
# 5.Dian
# 6.Delia
# 7.Afra

# %%
# !g++ --version
# Out:
# g++ (Ubuntu 13.3.0-6ubuntu2~24.04.1) 13.3.0
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# %%writefile praktik_variabel.cpp
# #include <iostream>
# #include <string>
# using namespace std;
#
# int main(){
# //Deklarasi Variabel Dan Tipe Data
# string namaBarang ="Laptop Asus";
# int jumlah =2;
# float harga =7500000.50;
# char kategori ='A';
# bool tersedia =true;
#
#   // Menampilkan Output ke Layar
#   cout<<"=== DATA INVENTARIS ==="<<endl;
#   cout<<"Nama Barang :"<< namaBarang<<endl;
#   cout<<"Kategori :"<<kategori<<endl;
#   cout<<"Jumlah :"<<jumlah<<endl;
#   cout<<"Harga :Rp"<<harga<<endl;
#   cout<<"Tersedia :"<<tersedia<<"(1 Ya, 0 Tidak)" << endl;
#   cout<<"======================="<<endl;
#
#
#   return 0;
# }
# Out:
# Overwriting praktik_variabel.cpp

# %%
# !g++ praktik_variabel.cpp -o praktik_variabel

# %%
# !./praktik_variabel
# Out:
# === DATA INVENTARIS ===
# Nama Barang :Laptop Asus
# Kategori :A
# Jumlah :2
# Harga :Rp7.5e+06
# Tersedia :1(1 Ya, 0 Tidak)
# ...
