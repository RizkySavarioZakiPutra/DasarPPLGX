# %% [markdown]
# <a href="https://colab.research.google.com/github/RizkySavarioZakiPutra/DasarPPLGX/blob/main/X_PPLG_RIZKYSAVARIOZAKIPUTRA_TUGAS_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tugas 2 Praktik Membuat Program Interaktif Menggunakan Cin Untuk Menerima Ketikan Dari Penggunna
# Nama Kelompok: NovaCrew Nama Anggota: 1.Azril 2.Rizky 3.Rafa Maul 4.Dava 5.Dian 6.Delia 7.Afra

# %%
# !g++ --version
# Out:
# g++ (Ubuntu 13.3.0-6ubuntu2~24.04.1) 13.3.0
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# %%writefile input_data.cpp
# #include <iostream>
# #include <string>
# using namespace std;
#
# int main(){
#   string namaSiswa;
#   int umur;
#
#   cout<<"Masukkan Nama (1 Kata):";
#   cin>>namaSiswa;
#
#   cout<<"Massukan Umur Anda :";
#   cin>>umur;
#
#   cout<<"\nHalo"<<namaSiswa<<",ternyata umur kamu"<<umur<<"tahun ya!"<<endl;
#   return 0;
# }
# Out:
# Overwriting input_data.cpp

# %%
# !g++ input_data.cpp -o input_data

# %%
# !./input_data
# Out:
# Masukkan Nama (1 Kata):tes
# Massukan Umur Anda :7
#
# Halotes,ternyata umur kamu7tahun ya!
