# %% [markdown]
# <a href="https://colab.research.google.com/github/RizkySavarioZakiPutra/DasarPPLGX/blob/main/NOVACREW_IKY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TUGAS MEMBUAT MENGHITUNG KELILING PERSEGI PANGJANG
#
# NAMA KELOMPOK: NOVA
#  1.Afra
#  2.Dava
#  3.Azril
#  4.Rizky
#  5.Rapaip
#  6.Delia
#  7.Dian

# %%
# !g++ --version
# Out:
# g++ (Ubuntu 13.3.0-6ubuntu2~24.04.1) 13.3.0
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# %%writefile kelilingpersegipanjang.cpp
# #include <iostream>
# using namespace std;
# int main ()
# {
#  int p,l,keliling;
#  cout <<"massukan panjang"<<endl;
#  cin>>p;
#  cout <<"masukkan lebar"<<endl;
#  cin>>l;
#  keliling=2*p+l;
#  cout<<"keliling persegi panjang adalah "<<keliling<<endl;
#  return 0;
# }
# Out:
# Overwriting kelilingpersegipanjang.cpp

# %%
# !g++ kelilingpersegipanjang.cpp -o main

# %%
! ./main
# Out:
# massukan panjang
# 19
# masukkan lebar
# 22
# keliling persegi panjang adalah 60
